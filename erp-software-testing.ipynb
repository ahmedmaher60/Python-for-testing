# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
import unittest

# %%
import unittest

class TestInventory(unittest.TestCase):
    def setUp(self):
        self.inventory = Inventory()

    def test_add_product(self):
        self.inventory.add_product(product_id=1, product_name="Widget", qty=100)
        self.assertEqual(self.inventory.get_product(product_id=1), {"product_id": 1, "product_name": "Widget", "qty": 100})

    def test_update_product_qty(self):
        self.inventory.add_product(product_id=1, product_name="Widget", qty=100)
        self.inventory.update_product_qty(product_id=1, qty_delta=10)
        self.assertEqual(self.inventory.get_product(product_id=1)["qty"], 110)

    def test_get_product_not_found(self):
        with self.assertRaises(ProductNotFoundError):
            self.inventory.get_product(product_id=1)

    def test_update_product_qty_insufficient_qty(self):
        self.inventory.add_product(product_id=1, product_name="Widget", qty=100)
        with self.assertRaises(InsufficientQtyError):
            self.inventory.update_product_qty(product_id=1, qty_delta=-110)
            
if __name__ == "__main__":
    unittest.main()
# Out:
# E
# ...
# ERROR: /root/ (unittest.loader._FailedTest)
# ----------------------------------------------------------------------
# AttributeError: module '__main__' has no attribute '/root/'
#
# ----------------------------------------------------------------------
# Ran 1 test in 0.001s
#
# FAILED (errors=1)
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit: True
# /opt/conda/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3560: UserWarning: To exit: use 'exit', 'quit', or Ctrl-D.
#   warn("To exit: use 'exit', 'quit', or Ctrl-D.", stacklevel=1)

# %%
import unittest

class TestAccountsPayable(unittest.TestCase):
    def setUp(self):
        self.accounts_payable = AccountsPayable()

    def test_add_invoice(self):
        self.accounts_payable.add_invoice(invoice_number=123, vendor_name="ACME Inc.", amount=1000.00)
        self.assertEqual(self.accounts_payable.get_invoice(invoice_number=123), {"invoice_number": 123, "vendor_name": "ACME Inc.", "amount": 1000.00})

    def test_pay_invoice(self):
        self.accounts_payable.add_invoice(invoice_number=123, vendor_name="ACME Inc.", amount=1000.00)
        self.accounts_payable.pay_invoice(invoice_number=123, amount=1000.00)
        self.assertEqual(self.accounts_payable.get_invoice(invoice_number=123)["status"], "paid")

    def test_invalid_invoice(self):
        with self.assertRaises(InvalidInvoiceError):
            self.accounts_payable.pay_invoice(invoice_number=123, amount=1000.00)
if __name__ == "__main__":
    unittest.main()
# Out:
# E
# ...
# ERROR: /root/ (unittest.loader._FailedTest)
# ----------------------------------------------------------------------
# AttributeError: module '__main__' has no attribute '/root/'
#
# ----------------------------------------------------------------------
# Ran 1 test in 0.001s
#
# FAILED (errors=1)
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit: True
# /opt/conda/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3560: UserWarning: To exit: use 'exit', 'quit', or Ctrl-D.
#   warn("To exit: use 'exit', 'quit', or Ctrl-D.", stacklevel=1)
